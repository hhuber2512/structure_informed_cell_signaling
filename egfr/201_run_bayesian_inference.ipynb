# %%
using Serialization, Distributions, AffineInvariantMCMC, StableRNGs 
include("ode_problem.jl")
include("target_probability.jl")
include("define_likelihood_data.jl");

# %% [markdown]
# ### Name Run
#
# run: 201
# test data: pSHC
# augmented: no
# weighed by AF3 confidence: N/A
# prior offset: +/- 2
# binding prior offset: 0

# %%
run = "201"
# Out:
# "201"

# %% [markdown]
# Define Prior Distributions

# %%
#generate bounds for prior
bound_offset = [2,2]
binding_bound_offset = [0,0]
prior_bounds = return_prior_bounds_empirical(bound_offset, binding_bound_offset) #for target probability
prior_distributions = [Uniform(prior_bounds[i]...) for i in 1:length(prior_bounds)];

# %% [markdown]
# Define Test/Train Data

# %%
#first input we need are data points and each point's associated standard deviation to evaluate the likelihood
data_points = deserialize("outputs/000_training_data_w_pshc_test.dict")["response"]
std_dev = deserialize("outputs/000_training_data_w_pshc_test.dict")["average_error"]

#load different EGF ligand dosages needed to simulate all training data
ligand_dosages = return_ligand_dose_order_for_likelihood_w_pshc_test()

#provide function for indexing likelihood data - that is, non test data
training_data_indices = likelihood_w_pshc_test;

# %% [markdown]
# Define ODEProblems for different intial conditions

# %%
#next input we need is an ode problem
odeproblems = []
for egf in ligand_dosages
    odesys, u0, tspan, p = return_ode_problem_default_inputs(egf)
    prob = DifferentialEquations.ODEProblem(odesys, u0, tspan, p) #note p will be overwritten in first run of mcmc algorithm
    push!(odeproblems, prob)
end

# %% [markdown]
# Define ODE Solver Inputs

# %%
#and ode solver inputs, which are consistent for all simulations
odesolver_inputs = return_ode_problem_solver_default_inputs();

# %% [markdown]
# Define Type of ODESolution

# %%
#get type of ODEProblem solution
pred = DifferentialEquations.solve(odeproblems[1], odesolver_inputs["solver"], abstol=odesolver_inputs["abstol"], reltol=odesolver_inputs["reltol"], saveat=odesolver_inputs["saveat"])
ode_sol_type = typeof(pred);

# %% [markdown]
# Define Augmented Likelihood Term

# %%
#none needed for baseline data set

# %% [markdown]
# Define Target Distribution for Sampling

# %%
target_probability = parameters -> logprob_baseline(parameters, prior_distributions, data_points, std_dev, training_data_indices, ligand_dosages, odeproblems, odesolver_inputs, ode_sol_type)
# Out:
# #51 (generic function with 1 method)

# %% [markdown]
# Affine Invariant Sampler Hyperparameters

# %%
#affine invariant sampler hyperparameters
numdims = 50
numwalkers = 1000
thinning = 1
numsamples_perwalker = 1000
burnin = 1000
n_subchains = 70
a_burnin = 4
a = 2
rng = StableRNG(28475);

# %% [markdown]
# Run Affine Invariant Sampler from 0

# %%
x0 = Matrix{Float64}(undef,numdims,numwalkers)
for i in 1:numwalkers
    x0[:,i] = [rand(rng, prior_distributions[j]) for j in 1:numdims]
end

chain0, llhoodvals0 = AffineInvariantMCMC.sample(target_probability, numwalkers, x0, burnin, thinning, a_burnin, rng=rng)
serialize("outputs/$(run)_posterior_samples_subchain_0.jls", chain0)
serialize("outputs/$(run)_posterior_samples_likelihood_subchain_0.jls", llhoodvals0)

#release from RAM
chain0 = nothing
llhoodvals0 = nothing

for i in 1:n_subchains
    chain = deserialize("outputs/$(run)_posterior_samples_subchain_$(i-1).jls")
    chain, llhoodvals = AffineInvariantMCMC.sample(target_probability, numwalkers, chain[:, :, end], numsamples_perwalker, thinning, a, rng=rng)
    serialize("outputs/$(run)_posterior_samples_subchain_$(i).jls", chain)
    serialize("outputs/$(run)_posterior_samples_likelihood_subchain_$(i).jls", llhoodvals)
end
# Out:
# ┌ Warning: At t=100.9913051953551, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647051487341. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.055299558613519297, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.40726476778437. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=23.345799805644976, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.407264722255101. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.66103071412489, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072390157239973. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=42.50563970357391, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072206312256839. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=56.799386244992895, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072206942891818. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=23.236244900127236, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.399162886119343. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=10.101913882409388, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.402558057778656. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.2354357366861177, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.4057212952546445. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.004917184669720883, dt was forced below floating point epsilon 8.673617379884035e-19, and step error estimate = 1.407263241605162. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.003302751718848312, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.4072632409388812. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=103.5792359387276, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.407234737176423. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0008517960477958651, dt was forced below floating point epsilon 1.0842021724855044e-19, and step error estimate = 1.4072647877112878. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.002757424119696716, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.407264839081526. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0033299493765577516, dt was forced below floating point epsilon 4.336808689942018e-19, and step error estimate = 1.407264785767872. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=50.196028262547046, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072646276035927. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.5389481188630247, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4072647617324983. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=9.09184647996298, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072648249314441. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.237183812793364, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072647834438519. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.7796987101473654, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072648419191953. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.008278939365735568, dt was forced below floating point epsilon 1.734723475976807e-18, and step error estimate = 1.4072647552742419. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.8675340983908395, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072647788168742. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=42.60408599581099, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647690648825. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=62.472015449177285, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.407264772242383. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=29.04317413417876, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.407274190364995. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=85.71562979274697, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4073045296093212. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.13741964274269486, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.321385316192723. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.742501710884814, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4072647690927638. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=47.163047103281, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.407265288452464. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=14.870793312101087, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072647822431021. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=12.420346584350623, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072652388097695. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=28.2538599630736, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.407265740236293. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=30.55274447232343, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4073136312810768. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=67.60347995858027, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4074757420948067. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0012093043659220778, dt was forced below floating point epsilon 2.168404344971009e-19, and step error estimate = 1.4072649270338746. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0004590961825385301, dt was forced below floating point epsilon 5.421010862427522e-20, and step error estimate = 1.4072647840475174. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.00012669943296619453, dt was forced below floating point epsilon 2.710505431213761e-20, and step error estimate = 1.4072647601118646. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.526908741942352, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4072657740324086. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.04139535457734712, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.407264789990601. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.437053262612478, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.407265015654549. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=110.88524454345597, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647899195119. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=115.76628633843947, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.40726640400703. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=21.72962964300543, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4072651346631908. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=8.274947839175184, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213852672844555. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.12114343342908586, dt was forced below floating point epsilon 1.3877787807814457e-17, and step error estimate = 1.321384595411658. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=96.11273175200984, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647577059176. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.9045948697261159, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072647599173589. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=43.06331118453766, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.40726474956558. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=117.16669104428978, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647516279813. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.4656731658717578, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213846087125685. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.5214086797170285, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213847021113352. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.560840540263229, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072647548119415. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=30.212240152642927, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4072647845594006. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.21367225117726518, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.321388742398724. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.9845998213741436, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213989250097797. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=101.04216768718304, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4079488196120868. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=7.663798981444427, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4088045128563602. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=73.79896531339149, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4258998606511186. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=36.711930791616865, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4108345758174121. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.17810335103377947, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.407279414717941. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.0526468757235268, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4073851916411928. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.7976063925981445, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4073232337604598. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=7.054196855436084, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072647605891913. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=34.76364141238724, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.407264810951954. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=3.0314060910369593, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.4072647580588762. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.0337813934957976, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.407265013516411. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=8.933724455172737, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072657578447825. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.032094855990523, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.4072647485169194. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0656556209719507, dt was forced below floating point epsilon 1.3877787807814457e-17, and step error estimate = 1.4072647605641617. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.021653527097799486, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.4072647428155165. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=86.57517822189419, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072459432427904. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.02125468178127732, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.4072647781773897. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.6312599113442873, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.4072653670425397. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.37752011584051887, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.4072651357674462. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   0%|▏                                        |  ETA: 0:32:07┌ Warning: At t=1.1510641040634662, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213843371285257. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.02766475741312461, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.32138431483934. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0012979980921278172, dt was forced below floating point epsilon 2.168404344971009e-19, and step error estimate = 1.407264763762901. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.30996858594898763, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213713528128899. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.20796919091041186, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213738686490302. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.24938060044718008, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213727069942356. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=38.963310072363626, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647593313015. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=60.92165215041407, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647603137665. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=9.595901705208743, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072647552663151. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=59.50466433752395, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647676512304. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=40.332700068629784, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647676981895. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.023647590084538685, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.3213862834093861. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=31.431230047475562, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4071500890523638. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=20.963175561831342, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4070493443482062. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=9.916887980475947, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4071355446472302. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.1794986279624566, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.407215325572376. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0719963074929033, dt was forced below floating point epsilon 1.3877787807814457e-17, and step error estimate = 1.4072648444135085. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.032313142112407565, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.407264797853462. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0067860556266646065, dt was forced below floating point epsilon 8.673617379884035e-19, and step error estimate = 1.4072647586072806. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.953726164764876, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.4072647716914564. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=59.532859743003556, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.407264765963809. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=75.29945284652152, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3221865872738587. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=27.3973638148057, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3215613041692218. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=26.047479338179674, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.4072647537403296. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=14.606003167449813, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.4072647984889834. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=91.98843776432142, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072650858550413. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.6049718122423462, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213911363523545. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=3.0974465723868354, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213983692541673. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.607739357478918, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3214107865439306. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=43.45589630414711, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.407255061202025. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.045745532269907, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213852658304392. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=6.438494202528756, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384596451875. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=4.143579982659749, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213846022802342. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.914604679195788, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845979788905. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=14.000054294479746, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213846041498267. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=7.911561690101231, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845995630402. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.0341475506656884, dt was forced below floating point epsilon 6.938893903907228e-18, and step error estimate = 1.4072648463044777. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.020565639065277884, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.4072647994730298. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=37.78968343859381, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072648299502708. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.03033380685202003, dt was forced below floating point epsilon 3.469446951953614e-18, and step error estimate = 1.4072647990367735. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.008000868622205741, dt was forced below floating point epsilon 1.734723475976807e-18, and step error estimate = 1.407264789722181. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.004750570501668404, dt was forced below floating point epsilon 8.673617379884035e-19, and step error estimate = 1.4072647657820476. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.4620580349186865, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.4072433792931327. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.39650137693083015, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.407298281563365. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.5816491341582495, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.407462803572718. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.3429764516401774, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.4073284144786338. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ...
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  21%|████████▊                                |  ETA: 0:29:46┌ Warning: At t=72.49271561646297, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213869787308832. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  25%|██████████▎                              |  ETA: 0:28:08┌ Warning: At t=6.98204618849797, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845509536197. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  28%|███████████▍                             |  ETA: 0:27:00┌ Warning: At t=30.88600944629256, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.321384643401494. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=116.58162937631543, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845872977712. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  31%|████████████▊                            |  ETA: 0:25:40┌ Warning: At t=13.33247152483169, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845947502152. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  32%|█████████████                            |  ETA: 0:25:26┌ Warning: At t=31.19346298452969, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846331991113. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  52%|█████████████████████▎                   |  ETA: 0:17:53┌ Warning: At t=4.229042783896052, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845962569617. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  53%|█████████████████████▊                   |  ETA: 0:17:26┌ Warning: At t=58.373344815873, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384595496397. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=50.83554418880755, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846320586309. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  55%|██████████████████████▋                  |  ETA: 0:16:39┌ Warning: At t=0.29308663423423803, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213839458387222. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  57%|███████████████████████▌                 |  ETA: 0:15:52┌ Warning: At t=2.8103536014691297, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.321384595032495. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  60%|████████████████████████▌                |  ETA: 0:14:51┌ Warning: At t=93.89711053658345, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845990069544. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  61%|█████████████████████████▏               |  ETA: 0:14:17┌ Warning: At t=116.88318665584434, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845965019808. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  65%|██████████████████████████▋              |  ETA: 0:12:56┌ Warning: At t=0.25804762593479375, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845946430505. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  66%|███████████████████████████▎             |  ETA: 0:12:23┌ Warning: At t=0.347539882350202, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845761903065. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.8210702968468105, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845761295966. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  70%|████████████████████████████▊            |  ETA: 0:11:03┌ Warning: At t=0.43596936888517457, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845907381845. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  76%|███████████████████████████████▏         |  ETA: 0:08:56┌ Warning: At t=4.07305048385241, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384594960386. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  77%|███████████████████████████████▋         |  ETA: 0:08:29┌ Warning: At t=11.325871560130366, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384597704017. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  79%|████████████████████████████████▎        |  ETA: 0:07:56┌ Warning: At t=89.22037561326066, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846495234147. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  80%|█████████████████████████████████        |  ETA: 0:07:16┌ Warning: At t=5.695856491043195, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384594895776. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  81%|█████████████████████████████████▍       |  ETA: 0:06:56┌ Warning: At t=1.5841092993113866, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845951239607. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  82%|█████████████████████████████████▉       |  ETA: 0:06:29┌ Warning: At t=41.574619952089115, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845966440405. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=57.27498386052913, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845966116327. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  85%|██████████████████████████████████▊      |  ETA: 0:05:36┌ Warning: At t=60.50085324580943, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845946079779. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  85%|██████████████████████████████████▉      |  ETA: 0:05:29┌ Warning: At t=6.062080979933715, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384594879981. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  89%|████████████████████████████████████▌    |  ETA: 0:04:02┌ Warning: At t=23.83854201175394, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.321384595933849. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  91%|█████████████████████████████████████▏   |  ETA: 0:03:29┌ Warning: At t=57.77005765269405, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846070591972. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  91%|█████████████████████████████████████▎   |  ETA: 0:03:22┌ Warning: At t=0.40791971641353114, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845948103624. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▌   |  ETA: 0:03:09┌ Warning: At t=4.3572666629837915, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845926438237. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  94%|██████████████████████████████████████▍  |  ETA: 0:02:22┌ Warning: At t=5.545961241486354, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384595259523. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  95%|██████████████████████████████████████▉  |  ETA: 0:01:58┌ Warning: At t=7.598668298129812, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845818401415. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  95%|███████████████████████████████████████  |  ETA: 0:01:51┌ Warning: At t=18.277575198737193, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846334052923. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  99%|████████████████████████████████████████▊|  ETA: 0:00:11┌ Warning: At t=25.375490563650878, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845961607966. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:37:01

# %% [markdown]
# Run Affine Invariate Sampler from N Subchain

# %%
#start = 51
#stop = 70
#for i in start:stop
    #chain = deserialize("outputs/$(run)_posterior_samples_subchain_$(i-1).jls")
    #chain, llhoodvals = AffineInvariantMCMC.sample(target_probability, numwalkers, chain[:, :, end], numsamples_perwalker, thinning, a, rng=rng)
    #serialize("outputs/$(run)_posterior_samples_subchain_$(i).jls", chain)
    #serialize("outputs/$(run)_posterior_samples_likelihood_subchain_$(i).jls", llhoodvals)
#end
# Out:
# ┌ Warning: At t=5.194071257140165, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845952340433. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   1%|▎                                        |  ETA: 0:36:28┌ Warning: At t=31.954528048537842, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.321384597748104. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   1%|▌                                        |  ETA: 0:34:49┌ Warning: At t=1.410413780813532, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384594895844. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   2%|▉                                        |  ETA: 0:33:52┌ Warning: At t=34.096926134395915, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213854078286889. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   2%|█                                        |  ETA: 0:33:40┌ Warning: At t=16.958972357346013, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845958057224. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   6%|██▍                                      |  ETA: 0:32:06┌ Warning: At t=0.8179195222828886, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.321383223518303. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   7%|███                                      |  ETA: 0:31:33┌ Warning: At t=28.9455573445155, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845957163588. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   8%|███▌                                     |  ETA: 0:31:07┌ Warning: At t=50.257172985158846, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321302952810779. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▉                                     |  ETA: 0:30:48┌ Warning: At t=52.06936478313019, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384595288893. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  12%|█████                                    |  ETA: 0:29:44┌ Warning: At t=36.23417102676124, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384595498154. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  15%|██████▏                                  |  ETA: 0:28:48┌ Warning: At t=12.792594541039279, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213781732155039. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=17.988947342055162, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213778006930266. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=43.50433999597701, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213774922134731. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  17%|███████▏                                 |  ETA: 0:27:57┌ Warning: At t=0.4555754623442507, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384595140116. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.1845224808743606, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.32138459541842. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  18%|███████▎                                 |  ETA: 0:27:51┌ Warning: At t=10.93138296970363, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845952360743. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  18%|███████▌                                 |  ETA: 0:27:39┌ Warning: At t=0.8408782703107179, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845950785914. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  19%|███████▉                                 |  ETA: 0:27:20┌ Warning: At t=41.28145120645147, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.2677183019587668. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=80.53080452275562, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846012908292. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  20%|████████                                 |  ETA: 0:27:14┌ Warning: At t=20.86544809409579, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846414723627. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  21%|████████▊                                |  ETA: 0:26:37┌ Warning: At t=8.711814511989667, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.32138459501234. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  23%|█████████▍                               |  ETA: 0:26:06┌ Warning: At t=4.329902235382106, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845919195164. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  26%|██████████▋                              |  ETA: 0:25:05┌ Warning: At t=0.1677078812699229, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845950798786. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  30%|████████████▏                            |  ETA: 0:23:46┌ Warning: At t=55.21786085491688, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.26072365819389. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  32%|█████████████▎                           |  ETA: 0:22:50┌ Warning: At t=18.948480103798374, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845990264428. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  36%|██████████████▊                          |  ETA: 0:21:36┌ Warning: At t=38.75133753921309, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846477124975. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  37%|███████████████▎                         |  ETA: 0:21:12┌ Warning: At t=34.04952929170603, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845961932886. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  44%|██████████████████▎                      |  ETA: 0:18:45┌ Warning: At t=0.19261275535336378, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.321384590088726. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  48%|███████████████████▋                     |  ETA: 0:17:31┌ Warning: At t=41.85017556553353, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845954120103. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=101.85032957623129, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845961504351. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  55%|██████████████████████▌                  |  ETA: 0:15:11┌ Warning: At t=0.3998326540363241, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845709135932. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  58%|███████████████████████▊                 |  ETA: 0:14:10┌ Warning: At t=1.1028617337819857, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384589976831. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  58%|████████████████████████                 |  ETA: 0:13:58┌ Warning: At t=0.9803940416916261, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213831772270737. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  63%|█████████████████████████▉               |  ETA: 0:12:27┌ Warning: At t=2.977418421291093, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845928281562. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  64%|██████████████████████████▌              |  ETA: 0:11:56┌ Warning: At t=21.07198206700575, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.2475588843728642. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  65%|██████████████████████████▋              |  ETA: 0:11:50┌ Warning: At t=53.40036642210248, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846253424442. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  66%|███████████████████████████              |  ETA: 0:11:26┌ Warning: At t=41.33992021517136, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384599432116. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  72%|█████████████████████████████▌           |  ETA: 0:09:25┌ Warning: At t=1.2385890896297016, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845950481362. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.364024050755623, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845950742626. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=11.769773444354398, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845956905006. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=21.71139573797464, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845965097886. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=15.4510449600903, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845956442916. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  77%|███████████████████████████████▋         |  ETA: 0:07:42┌ Warning: At t=21.595240601209372, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845952094605. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  82%|█████████████████████████████████▊       |  ETA: 0:05:59┌ Warning: At t=45.13799747936738, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846084463978. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  83%|██████████████████████████████████▎      |  ETA: 0:05:35┌ Warning: At t=21.947957801549872, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845990254292. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  85%|██████████████████████████████████▋      |  ETA: 0:05:11┌ Warning: At t=27.411182074126764, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.321384595361723. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=1.047221454022265, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845952426349. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  91%|█████████████████████████████████████▏   |  ETA: 0:03:10┌ Warning: At t=88.50297919150651, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384629670665. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  96%|███████████████████████████████████████▍ |  ETA: 0:01:21┌ Warning: At t=1.6083341206989141, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384595466376. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  97%|███████████████████████████████████████▉ |  ETA: 0:00:56┌ Warning: At t=53.13149309777111, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845986743635. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  99%|████████████████████████████████████████▉|  ETA: 0:00:08┌ Warning: At t=62.63615951920592, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845965463127. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:33:36
# ┌ Warning: At t=2.1098826767532106, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845935328221. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   1%|▍                                        |  ETA: 0:33:57┌ Warning: At t=3.862077661600214, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845950758256. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   6%|██▍                                      |  ETA: 0:31:52┌ Warning: At t=3.0821121940834155, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845948722795. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=4.43342807262723, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845949273946. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  14%|█████▌                                   |  ETA: 0:29:07┌ Warning: At t=33.01693183204332, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.4072647509250884. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  20%|████████▏                                |  ETA: 0:26:59┌ Warning: At t=20.53554798920523, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845965358868. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=33.62823087341562, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845979278673. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  21%|████████▊                                |  ETA: 0:26:29┌ Warning: At t=41.33767671723124, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846505210705. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  26%|██████████▋                              |  ETA: 0:24:58┌ Warning: At t=30.13928838476763, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846057916403. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  28%|███████████▌                             |  ETA: 0:24:15┌ Warning: At t=109.21624322716568, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846016096191. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  33%|█████████████▍                           |  ETA: 0:22:38┌ Warning: At t=67.6343547880211, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845966399376. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  36%|██████████████▊                          |  ETA: 0:21:31┌ Warning: At t=87.99328547631653, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321385022001603. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  37%|███████████████▎                         |  ETA: 0:21:07┌ Warning: At t=6.981985619634107, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845945357692. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  42%|█████████████████▏                       |  ETA: 0:19:36┌ Warning: At t=7.234433235488431, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213766660247457. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  43%|█████████████████▋                       |  ETA: 0:19:12┌ Warning: At t=0.40356531424588926, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845810291929. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.5869386568096961, dt was forced below floating point epsilon 1.1102230246251565e-16, and step error estimate = 1.3213845850311798. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=2.7096439932323957, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845961116926. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  44%|██████████████████▎                      |  ETA: 0:18:41┌ Warning: At t=77.53356793255337, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384597432844. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  47%|███████████████████▎                     |  ETA: 0:17:53┌ Warning: At t=24.60632613874067, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845964010762. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  49%|████████████████████▏                    |  ETA: 0:17:05┌ Warning: At t=1.84191520287803, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384595069842. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  50%|████████████████████▋                    |  ETA: 0:16:40┌ Warning: At t=104.73105542740028, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647334321904. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  54%|██████████████████████                   |  ETA: 0:15:34┌ Warning: At t=46.155712703566614, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845953986643. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  55%|██████████████████████▍                  |  ETA: 0:15:16┌ Warning: At t=6.124184893943252, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.32138459553347. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  57%|███████████████████████▌                 |  ETA: 0:14:21┌ Warning: At t=46.722505047616124, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384623136236. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  60%|████████████████████████▋                |  ETA: 0:13:27┌ Warning: At t=0.18831781021228602, dt was forced below floating point epsilon 2.7755575615628914e-17, and step error estimate = 1.3213845945576248. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  60%|████████████████████████▊                |  ETA: 0:13:21┌ Warning: At t=92.5813524528461, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845938194957. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  62%|█████████████████████████▍               |  ETA: 0:12:50┌ Warning: At t=13.999086026429184, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845961636648. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  62%|█████████████████████████▋               |  ETA: 0:12:38┌ Warning: At t=25.260179550004896, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845962252249. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  64%|██████████████████████████▏              |  ETA: 0:12:14┌ Warning: At t=4.756164626525843, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845950329872. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  65%|██████████████████████████▊              |  ETA: 0:11:44┌ Warning: At t=0.37495508904251934, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845950770646. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=0.4650615259584306, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321384595048278. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  67%|███████████████████████████▌             |  ETA: 0:11:02┌ Warning: At t=1.8279370976435425, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845942651201. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  68%|███████████████████████████▉             |  ETA: 0:10:43┌ Warning: At t=3.365829254118747, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845951829213. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  74%|██████████████████████████████▍          |  ETA: 0:08:42┌ Warning: At t=5.372001479776976, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384595845525. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=42.13404565774759, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384603598974. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  76%|███████████████████████████████▎         |  ETA: 0:08:00┌ Warning: At t=1.7712067062448948, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.3213845102875847. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  79%|████████████████████████████████▍        |  ETA: 0:07:06┌ Warning: At t=0.31180802146005543, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845933641646. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  84%|██████████████████████████████████▋      |  ETA: 0:05:17┌ Warning: At t=1.4034396045479545, dt was forced below floating point epsilon 2.220446049250313e-16, and step error estimate = 1.321384593448252. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  87%|███████████████████████████████████▋     |  ETA: 0:04:22┌ Warning: At t=18.49010305595477, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.2645555425696222. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  89%|████████████████████████████████████▍    |  ETA: 0:03:46┌ Warning: At t=7.076853469611777, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845952218815. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=12.50509013132333, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845954741528. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▋   |  ETA: 0:02:45┌ Warning: At t=15.93192823964467, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213846020142128. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  93%|██████████████████████████████████████▎  |  ETA: 0:02:15┌ Warning: At t=77.56302763287462, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072647542837988. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  95%|██████████████████████████████████████▉  |  ETA: 0:01:45┌ Warning: At t=31.641110429156992, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.321384622515204. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  95%|███████████████████████████████████████▏ |  ETA: 0:01:33┌ Warning: At t=5.707764390040842, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.321384687947477. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  97%|███████████████████████████████████████▋ |  ETA: 0:01:09┌ Warning: At t=0.44876998940384827, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.321380174296639. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:33:38
# Progress:   0%|▏                                        |  ETA: 0:35:28┌ Warning: At t=38.182631330758305, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213843338603093. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   1%|▎                                        |  ETA: 0:34:51┌ Warning: At t=62.77144512783037, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846337450965. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=82.15912859988595, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846640306193. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   1%|▌                                        |  ETA: 0:34:03┌ Warning: At t=5.536090696647643, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845943033864. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   4%|█▊                                       |  ETA: 0:32:29┌ Warning: At t=66.44141511603529, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.32138313347714. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   5%|██                                       |  ETA: 0:32:14┌ Warning: At t=111.31127797700046, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384618320608. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   5%|██▎                                      |  ETA: 0:32:01┌ Warning: At t=7.758710630713162, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845929754873. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▋                                     |  ETA: 0:30:52┌ Warning: At t=0.4384138884795427, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845949137912. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# ...
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=35.11359103461509, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213848359577405. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  79%|████████████████████████████████▌        |  ETA: 0:07:08┌ Warning: At t=76.6662359614581, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845957840191. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=54.232297840047224, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384286877644. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  81%|█████████████████████████████████▏       |  ETA: 0:06:38┌ Warning: At t=4.222764030710838, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845951545198. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  81%|█████████████████████████████████▍       |  ETA: 0:06:25┌ Warning: At t=75.40236393520429, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845964875754. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=9.041311404562462, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213843539434975. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  87%|███████████████████████████████████▌     |  ETA: 0:04:34┌ Warning: At t=22.30987564431635, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846454014981. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▋   |  ETA: 0:02:49┌ Warning: At t=3.020911841600784, dt was forced below floating point epsilon 4.440892098500626e-16, and step error estimate = 1.3213845953522994. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  92%|█████████████████████████████████████▊   |  ETA: 0:02:43┌ Warning: At t=112.6424597831462, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845016984755. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  99%|████████████████████████████████████████▌|  ETA: 0:00:27┌ Warning: At t=41.2982483462753, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845961608812. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:34:19
# Progress:   2%|█                                        |  ETA: 0:33:35┌ Warning: At t=5.162376911073895, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845927414707. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=10.33284209743124, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213845940174638. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▋                                     |  ETA: 0:31:21┌ Warning: At t=5.619754303426016, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845956335946. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▊                                     |  ETA: 0:31:15┌ Warning: At t=100.29476308146272, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384597429277. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:   9%|███▉                                     |  ETA: 0:31:09┌ Warning: At t=9.360456406758228, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213843481084302. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  14%|█████▉                                   |  ETA: 0:29:23┌ Warning: At t=71.87782756076517, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845941572773. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  24%|█████████▉                               |  ETA: 0:26:05┌ Warning: At t=32.98094287583785, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845652006062. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  36%|██████████████▋                          |  ETA: 0:22:04┌ Warning: At t=8.2744098740737, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.3213846015219508. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  41%|████████████████▊                        |  ETA: 0:20:19┌ Warning: At t=22.616334098432922, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845960595738. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  45%|██████████████████▍                      |  ETA: 0:18:59┌ Warning: At t=49.81674265034284, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213846011887207. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  49%|███████████████████▉                     |  ETA: 0:17:38┌ Warning: At t=73.25296121554858, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213846185928149. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  51%|█████████████████████                    |  ETA: 0:16:43┌ Warning: At t=0.4261788329117031, dt was forced below floating point epsilon 5.551115123125783e-17, and step error estimate = 1.3213845838446012. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  59%|████████████████████████▍                |  ETA: 0:13:56┌ Warning: At t=62.04482395204885, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213822864180491. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  70%|████████████████████████████▊            |  ETA: 0:10:14┌ Warning: At t=82.58896678903255, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.321384639239722. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  75%|██████████████████████████████▊          |  ETA: 0:08:35┌ Warning: At t=6.864632017643101, dt was forced below floating point epsilon 8.881784197001252e-16, and step error estimate = 1.3213845952102103. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  76%|███████████████████████████████▎         |  ETA: 0:08:10┌ Warning: At t=43.561793787194176, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213847264531215. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  80%|████████████████████████████████▊        |  ETA: 0:06:56┌ Warning: At t=23.396084899423137, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213845900303038. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  83%|██████████████████████████████████       |  ETA: 0:05:55┌ Warning: At t=19.61972794995072, dt was forced below floating point epsilon 3.552713678800501e-15, and step error estimate = 1.3213846317272822. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=8.447769860119573, dt was forced below floating point epsilon 1.7763568394002505e-15, and step error estimate = 1.321384594623261. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  83%|██████████████████████████████████▏      |  ETA: 0:05:49┌ Warning: At t=100.61070622933885, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.2712724812891198. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  84%|██████████████████████████████████▋      |  ETA: 0:05:24┌ Warning: At t=100.83610559747865, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.4072643002116982. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  87%|███████████████████████████████████▌     |  ETA: 0:04:35┌ Warning: At t=33.568026619142664, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.3213845952793744. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress:  91%|█████████████████████████████████████▎   |  ETA: 0:03:08┌ Warning: At t=62.9532575574869, dt was forced below floating point epsilon 7.105427357601002e-15, and step error estimate = 1.321384593397161. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# ┌ Warning: At t=79.52982739681146, dt was forced below floating point epsilon 1.4210854715202004e-14, and step error estimate = 1.3213845944243563. Aborting. There is either an error in your model specification or the true solution is unstable (or the true solution can not be represented in the precision of Float64).
# └ @ SciMLBase ~/.julia/packages/SciMLBase/Zrnkf/src/integrator_interface.jl:623
# Progress: 100%|█████████████████████████████████████████| Time: 0:34:25
